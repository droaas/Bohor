# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>الخطوة الاولى</span><span style='font-size:29px;line-height:  150%;font-family:"Arial","sans-serif";color:#0070C0;'>:</span></p>
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>بناء صور انماط التفعيلات لجميع البحور</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/1.png" style="width: 500px;"/>
# <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/17.png" style="width: 500px;"/>
# <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images//18.png" style="width: 500px;"/>

# %%
import pandas as pd
import numpy as np

##### حالات العلل والزحاف في العروض والضراب
ad_cases=pd.read_csv('corpus\\arod_drb_cases.csv',sep='\t',encoding='utf-16')
seas_tafilat_code=pd.read_csv('corpus\\Seas_cases.csv',sep='\t',encoding='utf-16')
ailla_zihaf=pd.read_csv('corpus\\ailla_zihaf.csv',sep='\t',encoding='utf-16')
##########
si = pd.read_csv('corpus\\Seas_info.csv', sep='\t', encoding='utf-16')
sea_dict = dict(zip(si['Snum'], si['Sname']))
########### مثال لحالات الضرب والعروض
ad_cases.head()
#############
### استدعاء قواعد انماط التفعيلات التي تم اعداها اعتمادا على مرجعيين اساسيين  بالاضافة الى مراجعة خبراء في العروض
ard_drb=pd.read_csv('corpus\\rule1_ard_drb.csv',sep='\t',encoding='utf-16')
hsho_info=pd.read_csv('corpus\\rule2_hsho_info.csv',sep='\t',encoding='utf-16')
hsho_tfilah=pd.read_csv('corpus\\rule3_hsho_tfilah.csv',sep='\t',encoding='utf-16')
ver_info=pd.read_csv('corpus\\rule4_byt_info.csv',sep='\t',encoding='utf-16')
# استدعاء معلومات البحور
si=pd.read_csv('corpus\\Seas_info.csv',sep='\t',encoding='utf-16')
sc=seas_tafilat_code.copy()
#sc=pd.read_csv('corpus\\Seas_cases.csv',sep='\t',encoding='utf-16')

# %%
cse=[]
def get_arroth_seting(sid,arod_drb_case,hshw_info):
    aid=[];adc=[]
    for i in arod_drb_case:
        for d in arod_drb_case[i]:
            aid.append(i)
            adc.append(d)
    adf=pd.DataFrame({'sids':[sid for i in range(len(aid))],'aid':aid,'adc':adc})

    hc=[i for i in hshw_info["case"]]
    hcs=pd.DataFrame({'sids':[sid for i in range(len(hc))],'hc':hc})

    pt=[i for i in hshw_info["pt"]]
    ft=[i for i in hshw_info["ft"]]
    ptft=pd.DataFrame({'sids':[sid for i in range(len(pt))],'pt':pt,'ft':ft})
    cse.append([sid,hshw_info["count"],hshw_info["start"],hshw_info["end"]])
    return adf,hcs,ptft,cse

########### مثال لحالات الضرب والعروض
ad_cases.head()
# Out:
#    Cid                                        Case
# 0    1             العروض والضرب صحيحان ولم يعتلان
# 1    2         علة دخلت على العروض واجازها العلماء
# 2    3          علة دخلت على الضرب واجازها الجمهور
# 3    4  علة دخلت على العروض والضرب واجازها الجمهور
# 4    5     علة دخلت على العروض واجازها بعض الجمهور

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الطويل</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/1.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
sid=1
# حالات الضراب والعروض
arod_drb_case={
    "4":["21","22","23","24","33","32"],
    "7":["51","53","54","55"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2','5'],
          "count":6,
          "start":111111,
          "end":555555,
          "pt":[5,3,5,3, 5,3,5,3],
          "ft":[6,4,6,4, 6,4,6,4],
          }
adf,hcs,ptft,cse=get_arroth_seting(sid,arod_drb_case,hshw_info)
seas_tafilat_code[seas_tafilat_code.Sid==1]
#ailla_zihaf[ailla_zihaf.AZtype.isin([1,2])][["AZname","AZtype"]]
# Out:
#    Sid   Sname  tid    pat1   pat2   pat3         tafilh1   trmiz1  \
# 0    1  الطويل    1    صحيح   صحيح   سالم  مَفَاْعِيْلُنْ  1011010
# 1    1  الطويل    2  مقبوضة  مقبوض  مقبوض        مفاْعلنْ   110110
# 2    1  الطويل    3   محذوف  محذوف  محذوف         فعوْلنْ    11010
# 3    1  الطويل    4  مقصورة  مقصور  مقصور       مفاْعيْلْ   110100
# 4    1  الطويل    5  مكفوفة  مكفوف  مكفوف       مفاْعيْلُ   110101
#
#       tafilh2  trmiz2
# 0  فَعُوْلُنْ   11010
# 1       فعوْل    1101
# 2           _       0
# 3           _       0
# 4           _       0

# %%
sid=1
# حالات الضراب والعروض
arod_drb_case={
    "4":["21","22","23","24","33","32"],
    "7":["51","53","54","55"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2','5'],
          "count":6,
          "start":111111,
          "end":555555,
          "pt":[5,3,5,3, 5,3,5,3],
          "ft":[6,4,6,4, 6,4,6,4],
          }
adf,hcs,ptft,cse = get_arroth_seting(sid,arod_drb_case,hshw_info)

# %% [markdown]
# [Go to Verification](#Go_to_Verification)

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المديد</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/2.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
sid=2
# حالات الضراب والعروض
arod_drb_case={
    "1":["11","22","23","24","54","55"],
    "7":["16","18",\
         "26","28",\
         "61","62","63","64","68",\
         "71","72","73","74","78",\
         "81","82","83","84","88"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','6','7','8'],
          "count":4,
          "start":1111,
          "end":8888,
          "pt":[3,5,3, 3,5,3],
          "ft":[4,6,4, 4,6,4],
          }
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر البسيط</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/3.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
sid=3
# حالات الضراب والعروض
arod_drb_case={
    "1":["22","23"],
    "7":["51","53","54","55"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2','4','5'],
          "count":6,
          "start":111111,
          "end":555555,
          "pt":[5,3,5,3, 5,3,5,3],
          "ft":[6,4,6,4, 6,4,6,4],
          }

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء البسيط</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/3.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(3,2)
sid=4
# حالات الضراب والعروض
arod_drb_case={
    "1":["11","12","13",\
         "33",\
         "44","45"],
    "7":["16","17","18",\
         "36","37","38",\
         "46","47","48",\
         "61","62","63","64","65","66","67","68",\
         "71","72","73","74","75","76","77","78",\
         "81","82","83","84","85","86","87","88"\
        ]
             }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','6','7','8'],
          "count":4,
          "start":1111,
          "end":8888,
          "pt":[3,5,3, 3,5,3],
          "ft":[4,6,4, 4,6,4],
          }
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الوافر</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/6.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر الوافر

# %%
### صور تفعيلات بحر الوافر
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(4,1)
sid=6
# حالات الضراب والعروض 
arod_drb_case={
    "1":["22"],
    "7":["32","34","35",\
         "42","44","45",\
         "52","54","55"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','3','4','5'],
          "count":4,
          "start":1111,
          "end":5555}

hshw_info={"case":['1','3','4','5'],
          "count":4,
          "start":1111,
          "end":5555,
          "pt":[3,3,3, 3,3,3],
          "ft":[4,4,4, 4,4,4],
          }
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء الوافر</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/4.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء الوافر

# %%
### صور تفعيلات بحر مجزوء الوافر
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(4,1)
sid=7
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","13","22"],
    "7":["14","15",\
         "24","25",\
         "31","32","34","35",\
         "41","42","44","45",\
         "51","52","54","55"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','3','4','5'],
          "count":2,
          "start":11,
          "end":55,
          "pt":[3,3, 3,3],
          "ft":[4,4, 4,4],
          }
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الكامل</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/5.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات البحر الكامل

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(5,1)
sid=8
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12","13"],
    "2":["44", "43"],
    "7":["51","52","23","55","56","57","58","15",\
         "61","62","63","65","66","67","68","16",\
         "71","72","73","75","76","77","78","17"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','5','6','7','8'],
          "count":4,
          "start":1111,
          "end":8888,
          "pt":[3,3,3, 3,3,3],
          "ft":[4,4,4, 4,4,4]}
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء الكامل</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/5.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء الكامل

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(5,2)
sid=9
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12","13","14"],
    "7":["51","52","23","54","55","56","57","58","15",\
         "61","62","63","64","65","66","67","68","16",\
         "71","72","73","74","75","76","77","78","17"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','5','6','7','8'],
          "count":2,
          "start":11,
          "end":88,
          "pt":[3,3, 3,3],
          "ft":[4,4, 4,4]}
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المديد</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/6.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر الهزج

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(6,1)
sid=11
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12","13"],
    "7":["14"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','4','5'],
          "count":2,
          "start":11,
          "end":55,
          "pt":[3,3, 3,3],
          "ft":[4,4, 4,4]}
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الرجز</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/7.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر الرجز

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(7,1)
sid=12
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12","22"],
    "7":["13","14","15","16",\
         "23","24","25","26",\
         "31","32","33","34","35","36",\
         "41","42","43","44","45","46",\
         "51","52","53","54","55","56",\
         "61","62","63","64","65","66"]}


# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','3','4','5','6'],
          "count":4,
          "start":1111,
          "end":6666,
          "pt":[3,3,3, 3,3,3],
          "ft":[4,4,4, 4,4,4]}

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء الرجز</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/7.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء الرجز

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(7,2)
sid=13
# حالات الضراب والعروض
arod_drb_case={
    "1":["11"],
    "7":["13","14","15","31",\
         "33","34","35",\
         "41","43","44","45",\
         "51","53","54","55"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','3','4','5'],
          "count":2,
          "start":11,
          "end":55,
          "pt":[3,3, 3,3],
          "ft":[4,4, 4,4]}
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الرمل</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/8.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر الرمل

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(8,1)
sid=14
# حالات الضراب والعروض 
arod_drb_case={
    "1":["22","21","23"],
    "7":["24","25","26","27",\
         "41","42","43","44","46","47",\
         "51","52","53","54","56","57",\
         "61","62","63","64","66","67",\
         "71","72","73","74","76","77"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','4','5','6','7'],
          "count":4,
          "start":1111,
          "end":7777,
          "pt":[3,3,3, 3,3,3],
          "ft":[4,4,4, 4,4,4]}

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء الرمل</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/8.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء الرمل

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(8,2)
sid=15
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12","13"],
    "7":["14","15","16","17",\
         "41","42","43","44","46","47",\
         "51","52","53","54","56","57",\
         "61","62","63","64","66","67",\
         "71","72","73","74","76","77"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','4','5','6','7'],
          "count":2,
          "start":11,
          "end":77,
          "pt":[3,3, 3,3],
          "ft":[4,4, 4,4]}

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر السريع</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/9.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر السريع

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(9,1)
sid=16
# حالات الضراب والعروض
arod_drb_case={"1":["11","12","13","43","44"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','5','6','7'],
          "count":4,
          "start":1111,
          "end":7777,
          "pt":[5,5,3, 5,5,3],
          "ft":[6,6,4, 6,6,4],
          }

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# ### صور تفعيلات بحر مشطور السريع

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المنسرح</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/10.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر المنسرح

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(10,1)
sid=17
# حالات الضراب والعروض
arod_drb_case={
    "1":["12"],
    "7":["13",\
         "14","15","16",\
         "42","43","44","45","46",\
         "52","53","54","55","56",\
         "62","63","64","65","66"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','4','5','6'],
          "count":4,
          "start":1111,
          "end":6666,
          "pt":[3,5,3, 3,5,3],
          "ft":[4,6,4, 4,6,4],
          }
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المديد</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/4.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر منهك المنسرح

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الخفيف</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/11.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر الخفيف التام

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(11,1)
sid=18
# حالات الضراب والعروض
arod_drb_case={
    "1":["11","12","22"],
    "7":["13","15","16","17",\
         "31","32","33","35","36","37",\
         "41","42","43","45","46","47",\
         "51","52","53","55","56","57",\
         "71","72","73","75","76","77"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','3','4','5','7'],
          "count":4,
          "start":1111,
          "end":7777,
          "pt":[3,5,3, 3,5,3],
          "ft":[4,6,4, 4,6,4],
          }

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء الخفيف</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/11.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء الخفيف

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(11,2)
sid=19
# حالات الضراب والعروض
arod_drb_case={
    "1":["11","12"],
    "7":["13","15","16",\
         "31","32","33","35","36",\
         "41","42","43","45","46",\
         "51","52","53","55","56",\
         "61","62","63","65","66"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','3','4','5','6'],
          "count":2,
          "start":11,
          "end":77,
          "pt":[5,3, 5,3],
          "ft":[6,4, 6,4],
          }

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المضارع</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/12.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر المضارع

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(12,1)
sid=20
# حالات الضراب والعروض
arod_drb_case={
    "1":["11"],
    "7":["31"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2','3'],
          "count":2,
          "start":11,
          "end":33,
          "pt":[5,3, 5,3],
          "ft":[6,4, 6,4],
          }

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])
# حالات استثنائية
# اذ وقع الكف امتنع الخبن والعكس

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المقتضب</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/13.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر المقتضب

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(13,1)
sid=21
# حالات الضراب والعروض
arod_drb_case={"1":["11"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2'],
          "count":2,
          "start":11,
          "end":22,
          "pt":[5,3, 5,3],
          "ft":[6,4, 6,4],
          }
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المجتث</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/14.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر المجتث

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(14,1)
sid=23
st="1"
# حالات الضراب والعروض
arod_drb_case={
    "1":["11"],
    "7":["12","13","14","15",\
         "21","22","24","25",\
         "31","32","34","34",\
         "41","42","44","45"]
            }
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2','3','4'],
          "count":2,
          "start":11,
          "end":55,
          "pt":[5,3, 5,3],
          "ft":[6,4, 6,4]}

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])
# حالات استثنائية
# اذ وقع الكف امتنع الخبن والعكس

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المتقارب</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/15.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات البحر المتقارب

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(15,1)
sid=24
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12","13","14"],
    "4":["21","22","23","24",\
         "31","32","33","34",\
         "41","42","43","44"],
    "7":["51","52","53","54","55",\
         "15","25","35","45"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','5'],
          "count":6,
          "start":111111,
          "end":555555,
          "pt":[3,3,3,3, 3,3,3,3],
          "ft":[4,4,4,4, 4,4,4,4]}
# حالات استثنائية
# زحاف القبض يمتنع اذا كان قبل العروض الابتر
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء المتقارب</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/15.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء المتقارب

# %%
# حالات الضراب والعروض 
sid=25
arod_drb_case={
    "1":["33","34"],
    "7":["53","54"]}
# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','5'],
          "count":4,
          "start":1111,
          "end":5555,
          "pt":[3,3,3, 3,3,3],
          "ft":[4,4,4, 4,4,4]}

adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر المتدارك</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/16.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر المتدارك

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(16,1)
sid=26
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11"],
    "7":["12", "13",\
         "21","22","23",\
         "31","32","33"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','2','3'],
          "count":6,
          "start":111111,
          "end":333333,
          "pt":[3,3,3,3, 3,3,3,3],
          "ft":[4,4,4,4, 4,4,4,4]}
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر مجزوء المتدارك</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/16.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ### صور تفعيلات بحر مجزوء المتدارك

# %%
# (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
#pattern=get_pattern(16,2)
sid=27
# حالات الضراب والعروض 
arod_drb_case={
    "1":["11","12", "13"],
    "7":["14","15",\
         "41","42","43",\
         "51","52","53"]}

# التفعيلات التي يمكن ظهورها في الحشو
hshw_info={"case":['1','4','5'],
          "count":4,
          "start":1111,
          "end":5555,
          "pt":[3,3,3, 3,3,3],
          "ft":[4,4,4, 4,4,4]}
adf1,hcs1,ptft1,cse1=get_arroth_seting(sid,arod_drb_case,hshw_info)
############
adf=pd.concat([adf,adf1])
hcs=pd.concat([hcs,hcs1])
ptft=pd.concat([ptft,ptft1])

# %%
cse1= np.array(cse)
byt_case=pd.DataFrame({'sids':cse1[:,0],'count':cse1[:,1],'start':cse1[:,2],'end':cse1[:,3]})
#adf.to_csv('corpus\\rules1_ard_drb.csv',sep='\t',encoding='utf-16')
#hcs.to_csv('corpus\\rules2_hsho_info.csv',sep='\t',encoding='utf-16')
#ptft.to_csv('corpus\\rules3_hsho_tfilah.csv',sep='\t',encoding='utf-16')
#byt_case.to_csv('corpus\\rules4_byt_info.csv',sep='\t',encoding='utf-16')
#a=list(adf.adc)
if len([i for i in adf.adc if len(i)!=2])==0:
    print("لا يوجد خطأ في عداد حالات العروض")

if len([i for i in range(len(byt_case)) if int(byt_case.start.iloc[i])>int(byt_case.end.iloc[i])])==0:
    print("لا يوجد خطأ في عداد حالات الحشو")
# Out:
# لا يوجد خطأ في عداد حالات العروض
# لا يوجد خطأ في عداد حالات الحشو

# %% [markdown]
# <a id='Go_to_Verification'></a>

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:364.0pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>بناء قاعدة انماط التفعيلات للبحور المختلفة</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>الخطوة الثانية</span>
#                         <span style='font-size:20px;line-height:  150%;font-family:"Arial","sans-serif";color:#0070C0;'>:
#                         </span>
#                     </p>
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:18px;font-family:"Arial","sans-serif";color:#0070C0;'>إستدعاء وترتيب قواعد انماط التفعيلات لمراجعتها مع المراجع والخيراء</span>
#                     </p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
#### تصنيف البحور بحسب عدد التفعيلات
sid8=list(si[si.Tc==8].Snum)
sid6=list(si[si.Tc==6].Snum)
sid4=list(si[si.Tc==4].Snum)
sid3=list(si[si.Tc==3].Snum)
sid2=list(si[si.Tc==2].Snum)
###ترتيب قاعدة انماط التفعيلات
#####
seas=list(set(list(ard_drb.sids)))
arod=[];drob=[]
for i in range(len(ard_drb)):
    arod.append(list(sc[(sc.Sid==int(ard_drb.sids.iloc[i])) & (sc.tid==int(str(ard_drb.adc.iloc[i])[0]))].pat1)[0])
    drob.append(list(sc[(sc.Sid==int(ard_drb.sids.iloc[i])) & (sc.tid==int(str(ard_drb.adc.iloc[i])[1]))].pat2)[0])
ard_drb["Arod"]=arod
ard_drb["Drob"]=drob
# ترتيب حالات العروض
sea=[]; adc=[]; cases=[]
for i in seas:
    ad=ard_drb[ard_drb.sids==i]
    aid=list(set(list(ad.aid)))
    for j in aid:
        ad1=ad[ad.aid==j]
        case=["("+ad1.Arod.iloc[d]+ ", "+ ad1.Drob.iloc[d] + ")" for d in range(len(ad1))]
        sea.append(i)
        adc.append(j)
        cases.append(case)
arod_drob_cases=pd.DataFrame({'Sid':sea,'ADC':adc,'Cases':cases})
#list(set(list(ard_drb.Arod)))
## حالات الضرب والعروض المختلفة
print(len(ard_drb))
print(len(arod_drob_cases))
# Out:
# 436
# 48

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:21px;font-family:"Arial","sans-serif";color:#0070C0;'>مثال لحالات بحر الطويل</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
print("حالات العلة والزحاف القائمة مقام العلة الجائزة للعروض والضرب")
print(list(arod_drob_cases[(arod_drob_cases.Sid==1)&(arod_drob_cases.ADC==1)].Cases))
print("حالات الزحاف الاخرى الجائزة للعروض والضرب")
print(list(arod_drob_cases[(arod_drob_cases.Sid==1)&(arod_drob_cases.ADC==7)].Cases))
# Out:
# حالات العلة والزحاف القائمة مقام العلة الجائزة للعروض والضرب
# [['(مقبوضة, صحيح)', '(مقبوضة, مقبوض)', '(مقبوضة, محذوف)', '(مقبوضة, مقصور)', '(محذوف, محذوف)', '(محذوف, مقبوض)']]
# حالات الزحاف الاخرى الجائزة للعروض والضرب
# [['(مكفوفة, صحيح)', '(مكفوفة, محذوف)', '(مكفوفة, مقصور)', '(مكفوفة, مكفوف)']]

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>صور تفعيلات بحر الطويل بحسب المرجع الرئيسي</span></p>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/1.png" style="width: 600px;"/>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/17.png" style="width: 600px;"/>
#                     <img src="https://raw.githubusercontent.com/droaas/Bohor/main/images/18.png" style="width: 600px;"/>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>الخطوة الثالثة:</span></p>
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:normal;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:29px;font-family:"Arial","sans-serif";color:#0070C0;'>مجموعة الدوال اللازمة لبناء قاعدة انماط صور التفعيلات</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
# هذه الدالة تجلب التفعيلات التي يجب استبعادها عند اجتماع زحافين يفترض الا يجتمعا
# مثال رقم1: اذ وقع القبض امتنع الكف والعكس في بحر الطويل
def get_zihaf_conflict(tf,p,shtr_position,zhaf1,zhaf2):
    tid =[i for i in range(len(p)) if (len([j for j in p[i][:shtr_position] if j ==zhaf1])!=0)\
          and (len([j for j in p[i][shtr_position:] if j ==zhaf2])!=0)]
    tid1 =[i for i in range(len(p)) if (len([j for j in p[i][:shtr_position] if j ==zhaf2])!=0)\
          and (len([j for j in p[i][shtr_position:] if j ==zhaf1])!=0)]
    tid.extend(tid1)
    tf=tf[~tf.Tid.isin(tid)]
    return(tf)

# هذه الدالة تعالج الحالات الاستثناية التي تخرج عن قواعد تنميط العروض
def exception_handling(sid,tf,p):
    if sid==1:
        # استثناءات البحر الطويل
        # حالة رقم1: اذ وقع القبض امتنع الكف والعكس
        tf=get_zihaf_conflict(tf,p,4,"2","5")
    elif sid==2:
        # استثناءات البحر المديد
        # اذ وقع الكف امتنع الخبن والعكس
        tf=get_zihaf_conflict(tf,p,3,"6","7")
    elif sid==3:
        # استثناءات البحر البحر البسيط
        # اذ وقع القبض امتنع الكف والعكس
        tf=get_zihaf_conflict(tf,p,4,"2","5")
    elif sid==8:
        # استثناءات البحر الكامل
        # استبعاد التفعيلات اذ كانت كلها خالية من الصحة لانه يتحول الى بحر الرجز
        tid=[i for i in range(len(p)) if len([j for j in p[i] if j !="1"])!=6]
        tf=tf[tf.Tid.isin(tid)]
    elif sid==9:
        # استثناءات بحر مجزوء الكامل
        # استبعاد التفعيلات اذ كانت كلها خالية من الصحة لانه يتحول الى بحر الرجز
        tid=[i for i in range(len(p)) if len([j for j in p[i] if j !="1"])!=4]
        tf=tf[tf.Tid.isin(tid)]
    elif sid==11:
        # استثناءات بحر الهزج 
        # اذ وقع الكف امتنع القبض والعكس
        tf=get_zihaf_conflict(tf,p,2,"4","5")
    elif sid==14:
        # استثناءات بحر الرمل 
        # اذا كان الخبن في جزء امتنع الكف في الجزء الاخر
        tf=get_zihaf_conflict(tf,p,3,"4","5")
    elif sid==15:
        # استثناءات بحر مجزوء الرمل 
        # اذا كان الخبن في جزء امتنع الكف في الجزء الاخر
        tf=get_zihaf_conflict(tf,p,2,"4","5")
    elif sid==18:        
        # استثناءات بحر الخفيف 
        # اذ وقع الكف امتنع الخبن والعكس
        tf=get_zihaf_conflict(tf,p,3,"3","4")
    elif sid==19:        
        # استثناءات بحر مجزوء الخفيف 
        # اذ وقع الكف امتنع الخبن والعكس
        tf=get_zihaf_conflict(tf,p,2,"3","4")
    elif sid==20:        
        # استثناءات بحر المضارع 
        # اذ وقع الكف امتنع الخبن والعكس
        tf=get_zihaf_conflict(tf,p,2,"3","4")
    elif sid==23:        
        # استثناءات بحر المجتث 
        # اذ وقع الكف امتنع الخبن والعكس
        tf=get_zihaf_conflict(tf,p,2,"3","4")    
    elif sid==24:        
        # استثناءات بحر المتقارب 
        # زحاف القبض يمتنع اذا كان قبل العروض الابتر
        tid=[i for i in range(len(p)) if (p[i][2]=='5' and p[i][3]=='4')]
        tf=tf[~tf.Tid.isin(tid)]
    return tf


def get_all_patterns(sid,patt, p, tt, ttt,pt,ft):
    length=len(p[0])
    tid=[i for i in range(len(p))]
    
    if length==2:
        t=[[patt[i[0]], patt[i[1]]] for i in p]
        t = numpy.array(t)
        rawy, qafih=get_rway_qafiah([t[:,0][:,ft[0]][i]+t[:,1][:,ft[1]][i] for i in range(len(t))])
        tf=pd.DataFrame({'Sid':sid,'Tid':tid,'tcode':p,'type':tt , 'ttt':ttt ,'t1':t[:,0][:,2], 't2':t[:,1][:,0], 't3':'_',\
                         't4':'_', 't5':'_', 't6':'_','t7':'_','t8':'_','t11':t[:,0][:,pt[0]],'t12':t[:,1][:,pt[1]],'t13':'_',\
                         't14':'_', 't15':'_', 't16':'_','t17':'_','t18':'_','t21':t[:,0][:,ft[0]],'t22':t[:,1][:,ft[1]],\
                         't23':'0', 't24':'0', 't25':'0', 't26':'0','t27':'0','t28':'0','rawy':rawy, 'qafih':qafih})

        
    elif length==3:
        t=[[patt[i[0]], patt[i[1]],patt[i[2]]] for i in p]
        t = numpy.array(t)
        rawy, qafih=get_rway_qafiah([t[:,1][:,ft[1]][i]+t[:,2][:,ft[2]][i] for i in range(len(t))])
        tf=pd.DataFrame({'Sid':sid,'Tid':tid,'tcode':p,'type':tt ,'ttt':ttt,'t1':t[:,0][:,2],'t2':t[:,1][:,2],'t3':t[:,2][:,0],\
                         't4':'_', 't5':'_', 't6':'_','t7':'_','t8':'_','t11':t[:,0][:,pt[0]],'t12':t[:,1][:,pt[1]],\
                         't13':t[:,2][:,pt[2]],'t14':'_', 't15':'_', 't16':'_','t17':'_','t18':'_','t21':t[:,0][:,ft[0]],\
                         't22':t[:,1][:,ft[1]],'t23':t[:,2][:,ft[2]],'t24':'0', 't25':'0', 't26':'0','t27':'0','t28':'0',\
                         'rawy':rawy, 'qafih':qafih})
                         
    elif length==4:
        t=[[patt[i[0]], patt[i[1]],patt[i[2]],patt[i[3]]] for i in p]
        t = np.array(t)
        rawy, qafih=get_rway_qafiah([t[:,2][:,ft[2]][i]+t[:,3][:,ft[3]][i] for i in range(len(t))])
        tf=pd.DataFrame({'Sid':sid,'Tid':tid,'tcode':p,'type':tt , 'ttt':ttt ,'t1':t[:,0][:,2],'t2':t[:,1][:,0],\
                         't3':t[:,2][:,2],'t4':t[:,3][:,1], 't5':'_', 't6':'_','t7':'_','t8':'_','t11':t[:,0][:,pt[0]],\
                         't12':t[:,1][:,pt[1]],'t13':t[:,2][:,pt[2]],'t14':t[:,3][:,pt[3]],'t15':'_', 't16':'_','t17':'_',\
                         't18':'_','t21':t[:,0][:,ft[0]],'t22':t[:,1][:,ft[1]],'t23':t[:,2][:,ft[2]],'t24':t[:,3][:,ft[3]],\
                         't25':'0', 't26':'0','t27':'0','t28':'0','rawy':rawy, 'qafih':qafih})

    elif length==6:
        #print(p)
        t=[[patt[i[0]], patt[i[1]],patt[i[2]],patt[i[3]],patt[i[4]],patt[i[5]]] for i in p]
        t = np.array(t)
        rawy, qafih=get_rway_qafiah([t[:,4][:,ft[4]][i]+t[:,5][:,ft[5]][i] for i in range(len(t))])
        tf=pd.DataFrame({'Sid':sid,'Tid':tid,'tcode':p,'type':tt , 'ttt':ttt ,'t1':t[:,0][:,2],'t2':t[:,1][:,2],\
                         't3':t[:,2][:,0],'t4':t[:,3][:,2],'t5':t[:,4][:,2],'t6':t[:,5][:,1],'t7':'_','t8':'_',\
                         't11':t[:,0][:,pt[0]],'t12':t[:,1][:,pt[1]],'t13':t[:,2][:,pt[2]],'t14':t[:,3][:,pt[3]],\
                         't15':t[:,4][:,pt[4]],'t16':t[:,5][:,pt[5]],'t17':'_', 't18':'_',\
                         't21':t[:,0][:,ft[0]],'t22':t[:,1][:,ft[1]],'t23':t[:,2][:,ft[2]],'t24':t[:,3][:,ft[3]],\
                         't25':t[:,4][:,ft[4]],'t26':t[:,5][:,ft[5]],'t27':'0','t28':'0','rawy':rawy, 'qafih':qafih})
    elif length==8:
        t=[[patt[i[0]], patt[i[1]],patt[i[2]],patt[i[3]],patt[i[4]],patt[i[5]],patt[i[6]],patt[i[7]]] for i in p]
        #print(t)
        t = np.array(t)
        rawy, qafih=get_rway_qafiah([t[:,6][:,ft[6]][i]+t[:,7][:,ft[7]][i] for i in range(len(t))])
        tf=pd.DataFrame({'Sid':sid,'Tid':tid,'tcode':p,'type':tt , 'ttt':ttt ,'t1':t[:,0][:,2],'t2':t[:,1][:,2],\
                         't3':t[:,2][:,2],'t4':t[:,3][:,0],'t5':t[:,4][:,2],'t6':t[:,5][:,2],'t7':t[:,6][:,2],'t8':t[:,7][:,1],\
                         't11':t[:,0][:,pt[0]],'t12':t[:,1][:,pt[1]],'t13':t[:,2][:,pt[2]],'t14':t[:,3][:,pt[3]],\
                         't15':t[:,4][:,pt[4]],'t16':t[:,5][:,pt[5]],'t17':t[:,6][:,pt[6]],'t18':t[:,7][:,pt[7]],\
                         't21':t[:,0][:,ft[0]],'t22':t[:,1][:,ft[1]],'t23':t[:,2][:,ft[2]],'t24':t[:,3][:,ft[3]],\
                         't25':t[:,4][:,ft[4]],'t26':t[:,5][:,ft[5]],'t27':t[:,6][:,ft[6]],'t28':t[:,7][:,ft[7]],\
                         'rawy':rawy, 'qafih':qafih})
    return tf
#
def get_tafilah_pattern(sid,arod_drb_case,hshw_info,pattern):
    p1=[]; ad=int(hshw_info["count"]/2); n=0 ;arod_drb_cases=[];arod_drb_code=[]
    ### اختيار حالات تفعيلات الحشو كاملة
    p=[str(i) for i in range(hshw_info["start"],hshw_info["end"]+1)\
       if len([j for j in str(i) if j in hshw_info["case"]])==hshw_info["count"]]
    ### اضافة حالات تفعيلات العروض والضرب كاملة
    for i in arod_drb_case:
        n=0
        for d in arod_drb_case[i]:
            n=n+1            
            for j in p:
                p1.append(j[:ad]+d[0]+j[ad:]+d[1])
                arod_drb_cases.append(i)
                arod_drb_code.append(n)
    tf = get_all_patterns(sid,pattern,p1, arod_drb_cases, arod_drb_code,hshw_info["pt"],hshw_info["ft"])
    return tf,p1


def get_sea_pattern(sid):
    st=pd.read_csv('corpus\\Seas_cases.csv',sep='\t',encoding='utf-16')
    s=st[(st.Sid==sid)]
    pattern={}
    # (العلل والزحافات) حصر جميع التفعيلات الجائزة للبحر
    for i in range(len(s)):
        pattern[str(s.iloc[i,2])]=[s.iloc[i,3],s.iloc[i,4],s.iloc[i,5],s.iloc[i,6],str(s.iloc[i,7]),str(s.iloc[i,8]),\
                                        str(s.iloc[i,9])]
    return pattern

def get_arrwth_info(sid):
    # اخذ حالات الضرب والعروض
    ad=ard_drb[(ard_drb.sids==sid)]
    arod_drb_case={}
    set(list(ad.aid))
    for i in set(list(ad.aid)):
        arod_drb_case[i]= [str(i) for i in list(ad[ad.aid==i].adc)]

    # اخذ تفاصيل الحشو
    hshw_info={}
    hshw_info["case"]= [str(i) for i in list(hsho_info[(hsho_info.sids==sid)].hc)]
    hshw_info["count"]= int(int(ver_info[(ver_info.sids==sid)]["count"]))
    hshw_info["start"]= int(ver_info[(ver_info.sids==sid)]["start"])
    hshw_info["end"]= int(ver_info[(ver_info.sids==sid)]["end"])
    hshw_info["pt"]= list(hsho_tfilah[(hsho_tfilah.sids==sid)].pt)
    hshw_info["ft"]= list(hsho_tfilah[(hsho_tfilah.sids==sid)].ft)
    return arod_drb_case,hshw_info

def get_pattern(sid):
    pattern=get_sea_pattern(sid)
    arod_drb_case,hshw_info=get_arrwth_info(sid)
    #print(arod_drb_case)
    #print(hshw_info)
    tf,p=get_tafilah_pattern(sid,arod_drb_case,hshw_info,pattern)
    return tf,p

def get_rway_qafiah(end_agz): #
    rawy=[]
    for i in end_agz:
        if i != "0":
           # print(i[-1])
            if i[-1]   == "0":    rawy.append(2)
            elif i[-2] == "0":    rawy.append(3)
            elif i[-3] == "0":    rawy.append(4)
            elif i[-3] == "0":    rawy.append(5)
            elif i[-4] == "0":    rawy.append(6)
        else:
            rawy.append("0")
    qafih = [i for i in rawy]

    for i in range(len(end_agz)): #
        if end_agz[i] != "0" :
            if end_agz[i][-qafih[i]]     == "0":     qafih[i]=qafih[i]+1 
            elif end_agz[i][-(qafih[i]+1)] == "0":    qafih[i]=qafih[i]+2
            elif end_agz[i][-(qafih[i]+2)] == "0":    qafih[i]=qafih[i]+3
            elif end_agz[i][-(qafih[i]+3)] == "0":    qafih[i]=qafih[i]+4
            elif end_agz[i][-(qafih[i]+4)] == "0":    qafih[i]=qafih[i]+5
            elif end_agz[i][-(qafih[i]+5)] == "0":    qafih[i]=qafih[i]+6
    return rawy, qafih

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>حالة البناء رقم 1:</span></p>
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>بناء انماط اوزان البحور ثمانية التفعيلات </span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
for i in sid8:
    tf,p=get_pattern(i)
    #print(len(tf))
    tf=exception_handling(i,tf,p)
    #print(len(tf))
    tf=tf[(tf.t11!="_") & (tf.t12!="_") & (tf.t13!="_") & (tf.t15!="_") & (tf.t16!="_") & (tf.t17!="_")]
    if sid8.index(i) == 0:
        tafilat = tf.copy(deep=True)
    else:
        tafilat=pd.concat([tafilat,tf])
tafilat8 = tafilat.copy(deep=True)
print('عدد حالات البحور ثمانية التفعيلات',len(tafilat8))
#a=[i for i in range(len(tafilat8)) if len(str(tafilat8.t28.iloc[i]))<= tafilat8.qafih.iloc[i] ]
#tafilat8.iloc[a]
a=[i for i in range(len(tafilat8)) if len(str(tafilat8.t27.iloc[i])+str(tafilat8.t28.iloc[i]))<= tafilat8.qafih.iloc[i] ]
if len(a)==0:
    qtfilh=[(str(tafilat8.t27.iloc[i])+str(tafilat8.t28.iloc[i])) [-(tafilat8.qafih.iloc[i]):] for i in range(len(tafilat8))]
    qscope=[len(qtfilh[i][2:-(tafilat8.rawy.iloc[i]-1)]) for i in range(len(qtfilh))]
tafilat8["qtfilh"]=qtfilh
tafilat8["qscope"]=qscope
# Out:
# عدد حالات البحور ثمانية التفعيلات 9760

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>مثال على بعض صور انماط التفعيلات للبحور ثمانية التفعيلات</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
# البحور ثمانية التعلية
si[si.Tc==8]
# Out:
#     Snum  Sid  Stype     Sname  Tc
# 0      1    1      1    الطويل   8
# 2      3    3      1    البسيط   8
# 21    24   15      1  المتقارب   8
# 23    26   16      1  المتدارك   8

# %%
# عينة من انماط التفعيلات الثمانية
tafilat8.head()
# Out:
#    Sid  Tid     tcode  type  ttt    t1    t2    t3      t4     t5  ...    t23  \
# 0    1    0  11121111     1    1  سالم  سالم  سالم  مقبوضة   سالم  ...  11010
# 1    1    1  11121121     1    1  سالم  سالم  سالم  مقبوضة   سالم  ...  11010
# 3    1    3  11121211     1    1  سالم  سالم  سالم  مقبوضة   سالم  ...  11010
# 4    1    4  11121221     1    1  سالم  سالم  سالم  مقبوضة   سالم  ...  11010
# 9    1    9  11122111     1    1  سالم  سالم  سالم  مقبوضة  مقبوض  ...  11010
#
#       t24    t25      t26    t27      t28 rawy qafih qtfilh qscope
# 0  110110  11010  1011010  11010  1011010    2     4   1010      1
# 1  110110  11010  1011010   1101  1011010    2     4   1010      1
# 3  110110  11010   110110  11010  1011010    2     4   1010      1
# 4  110110  11010   110110   1101  1011010    2     4   1010      1
# 9  110110   1101  1011010  11010  1011010    2     4   1010      1
#
# [5 rows x 33 columns]

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:20px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>مثال لبعض صور بحور الطويل</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
tafilat8['Sname']=[sea_dict[i] for i in list(tafilat8.Sid)]
tafilat8[["Sname","t1","t2","t3","t4","t5","t6","t7","t8","t11","t12","t13","t14","t15","t16","t17","t18",\
        "t21","t22","t23","t24","t25","t26","t27","t28"]]
# Out:
#          Sname      t1      t2      t3       t4      t5      t6      t7  \
# 0       الطويل    سالم    سالم    سالم   مقبوضة    سالم    سالم    سالم
# 1       الطويل    سالم    سالم    سالم   مقبوضة    سالم    سالم   مقبوض
# 3       الطويل    سالم    سالم    سالم   مقبوضة    سالم   مقبوض    سالم
# 4       الطويل    سالم    سالم    سالم   مقبوضة    سالم   مقبوض   مقبوض
# 9       الطويل    سالم    سالم    سالم   مقبوضة   مقبوض    سالم    سالم
# ...        ...     ...     ...     ...      ...     ...     ...     ...
# 6556  المتدارك  مشعَّث  مشعَّث  مشعَّث  مشعَّثة  مشعَّث   مخبون   مخبون
# 6557  المتدارك  مشعَّث  مشعَّث  مشعَّث  مشعَّثة  مشعَّث   مخبون  مشعَّث
# 6558  المتدارك  مشعَّث  مشعَّث  مشعَّث  مشعَّثة  مشعَّث  مشعَّث    سالم
# 6559  المتدارك  مشعَّث  مشعَّث  مشعَّث  مشعَّثة  مشعَّث  مشعَّث   مخبون
# 6560  المتدارك  مشعَّث  مشعَّث  مشعَّث  مشعَّثة  مشعَّث  مشعَّث  مشعَّث
#
#           t8         t11  ...         t17             t18    t21      t22  \
# ...

# %% [markdown]
# [Go to Arud Rules](#Go_to_Arud_Rules)

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>حالة البناء رقم 2:</span></p>
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>بناء انماط اوزان البحور سداسية التفعيلات </span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
for i in sid6:
    if i!=10:
        tf,p=get_pattern(i)
        #print("After: ",len(tf))
        tf=exception_handling(i,tf,p)
        #print("Befor: ",len(tf))
        tf=tf[(tf.t11!="_") & (tf.t12!="_") & (tf.t14!="_") & (tf.t15!="_")]
        if sid6.index(i) == 0:
            tafilat = tf.copy(deep=True)
        else:
            tafilat=pd.concat([tafilat,tf])
#tafilat.to_csv('corpus\\tafilat6.csv',sep='\t',encoding='utf-16')
tafilat6 = tafilat.copy(deep=True)
print(len(tafilat6))
a=[i for i in range(len(tafilat6)) if len(str(tafilat6.t25.iloc[i])+str(tafilat6.t26.iloc[i]))<= tafilat6.qafih.iloc[i] ]
if len(a)==0:
    qtfilh=[(str(tafilat6.t25.iloc[i])+str(tafilat6.t26.iloc[i])) [-(tafilat6.qafih.iloc[i]):] for i in range(len(tafilat6))]
    qscope=[len(qtfilh[i][2:-(tafilat6.rawy.iloc[i]-1)]) for i in range(len(qtfilh))]
tafilat6["qtfilh"]=qtfilh
tafilat6["qscope"]=qscope
# Out:
# 66411

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>مثال على بعض صور انماط التفعيلات الممكنة لبحر الكامل</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
si[si.Tc==6]
# Out:
#     Snum  Sid  Stype           Sname  Tc
# 1      2    2      1          المديد   6
# 3      4    3      2    مجزوء البسيط   6
# 4      6    4      1          الوافر   6
# 6      8    5      1          الكامل   6
# 8     10    5      3      أحذ الكامل   6
# 10    12    7      1           الرجز   6
# 12    14    8      1           الرمل   6
# 14    16    9      1          السريع   6
# 15    17   10      1         المنسرح   6
# 16    18   11      1          الخفيف   6
# 22    25   15      2  مجزوء المتقارب   6
# 24    27   16      2  مجزوء المتدارك   6

# %%
tafilat6['Sname']=[sea_dict[i] for i in list(tafilat6.Sid)]
tafilat6[["Sname","t1","t2","t3","t4","t5","t6","t11","t12","t13","t14","t15","t16",\
        "t21","t22","t23","t24","t25","t26"]]
# Out:
#               Sname      t1      t2       t3      t4      t5          t6  \
# 0            المديد    سالم    سالم    صحيحة    سالم    سالم        صحيح
# 1            المديد    سالم    سالم    صحيحة    سالم   مخبون        صحيح
# 4            المديد    سالم    سالم    صحيحة   مخبون    سالم        صحيح
# 5            المديد    سالم    سالم    صحيحة   مخبون   مخبون        صحيح
# 8            المديد    سالم    سالم    صحيحة   مكفوف    سالم        صحيح
# ..              ...     ...     ...      ...     ...     ...         ...
# 886  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة   مخبون   مخبون  مخبون مرفل
# 887  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة   مخبون  مشعَّث  مخبون مرفل
# 888  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة  مشعَّث    سالم  مخبون مرفل
# 889  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة  مشعَّث   مخبون  مخبون مرفل
# 890  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة  مشعَّث  مشعَّث  مخبون مرفل
#
#                 t11      t12             t13             t14         t15  \
# ...

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>حالة البناء رقم 3:</span></p>
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>بناء انماط اوزان البحور رباعية التفعيلات </span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
for i in sid4:
    tf,p=get_pattern(i)
    #print("After: ",len(tf))
    tf=exception_handling(i,tf,p)
    #print("Befor: ",len(tf))
    tf=tf[(tf.t11!="_") & (tf.t13!="_")]
    if sid4.index(i) == 0:
        tafilat = tf.copy(deep=True)
    else:
        tafilat=pd.concat([tafilat,tf])
#tafilat.to_csv('corpus\\tafilat4.csv',sep='\t',encoding='utf-16')
tafilat4 = tafilat.copy(deep=True)
print(len(tafilat4))
a=[i for i in range(len(tafilat4)) if len(str(tafilat4.t23.iloc[i])+str(tafilat4.t24.iloc[i]))<= tafilat4.qafih.iloc[i] ]
if len(a)==0:
    qtfilh=[(str(tafilat4.t23.iloc[i])+str(tafilat4.t24.iloc[i])) [-(tafilat4.qafih.iloc[i]):] for i in range(len(tafilat4))]
    qscope=[len(qtfilh[i][2:-(tafilat4.rawy.iloc[i]-1)]) for i in range(len(qtfilh))]
tafilat4["qtfilh"]=qtfilh
tafilat4["qscope"]=qscope
# Out:
# 2153

# %% [markdown]
# <div align="center" style='margin-top:0in;margin-right:0in;margin-bottom:8.0pt;margin-left:0in;line-height:107%;font-size:15px;font-family:"Calibri","sans-serif";'>
#     <table dir="rtl" style="border-collapse:collapse;border:none;">
#         <tbody>
#             <tr>
#                 <td style="width:431.5pt;padding:0in 5.4pt 0in 5.4pt;">
#                     <p dir="RTL" style='margin-top:0in;margin-right:0in;margin-bottom:  .0001pt;margin-left:0in;line-height:150%;font-size:15px;font-family:"Calibri","sans-serif";text-align:center;'><span style='font-size:24px;line-height:150%;font-family:"Arial","sans-serif";color:#0070C0;'>مثال على بعض صور انماط التفعيلات الممكنة لبحر المنسرح</span></p>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
si[si.Tc==4]
# Out:
#     Snum  Sid  Stype         Sname  Tc
# 5      7    4      2  مجزوء الوافر   4
# 7      9    5      2  مجزوء الكامل   4
# 9     11    6      1         الهزج   4
# 11    13    7      2   مجزوء الرجز   4
# 13    15    8      2   مجزوء الرمل   4
# 17    19   11      2  مجزوء الخفيف   4
# 18    20   12      1       المضارع   4
# 19    21   13      1       المقتضب   4
# 20    23   14      1        المجتث   4

# %%
tafilat6['Sname']=[sea_dict[i] for i in list(tafilat6.Sid)]
tafilat6[["Sname","t1","t2","t3","t4","t11","t12","t13","t14","t21","t22","t23","t24"]]
# Out:
#               Sname      t1      t2       t3      t4             t11      t12  \
# 0            المديد    سالم    سالم    صحيحة    سالم  فَاْعِلَاْتُنْ  فاْعلنْ
# 1            المديد    سالم    سالم    صحيحة    سالم  فَاْعِلَاْتُنْ  فاْعلنْ
# 4            المديد    سالم    سالم    صحيحة   مخبون  فَاْعِلَاْتُنْ  فاْعلنْ
# 5            المديد    سالم    سالم    صحيحة   مخبون  فَاْعِلَاْتُنْ  فاْعلنْ
# 8            المديد    سالم    سالم    صحيحة   مكفوف  فَاْعِلَاْتُنْ  فاْعلنْ
# ..              ...     ...     ...      ...     ...             ...      ...
# 886  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة   مخبون          فعْلنْ   فعْلنْ
# 887  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة   مخبون          فعْلنْ   فعْلنْ
# 888  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة  مشعَّث          فعْلنْ   فعْلنْ
# 889  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة  مشعَّث          فعْلنْ   فعْلنْ
# 890  مجزوء المتدارك  مشعَّث  مشعَّث  مشعَّثة  مشعَّث          فعْلنْ   فعْلنْ
#
# ...
